# %%
# Monto il drive Google
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
# !pip install codecarbon dash dash-bootstrap-components fire pyngrok

# %% [markdown]
# **ATTENZIONE:**        E' ammesso il funzionamento di un solo blocco di codice per volta !

# %% [markdown]
# # MobileNet-V3 Small + BiLSTM

# %%
from pyngrok import ngrok
import subprocess

# !ngrok authtoken '2hs9Eao8fUVN21iEhE0uXVALvqf_3zETHYg3XTAUXE63cZ1s3'

filepath = "/content/gdrive/MyDrive/Modelli/MobileNet_V3_Small/BiLSTM/Emissioni_addestramento_MV3_BiLSTM.csv"
carbonboard_process = subprocess.Popen(['carbonboard', '--filepath', filepath, '--port', '3333'])
public_url = ngrok.connect(3333)
print(f"Access Carbonboard at: {public_url}")

# %% [markdown]
# # MobileNet-V3 Small + ConvLSTM

# %%
from pyngrok import ngrok
import subprocess

# !ngrok authtoken '2hs9Eao8fUVN21iEhE0uXVALvqf_3zETHYg3XTAUXE63cZ1s3'

filepath = "/content/gdrive/MyDrive/Modelli/MobileNet_V3_Small/ConvLSTM/emissions_V3Small_ConvLSTM.csv"
carbonboard_process = subprocess.Popen(['carbonboard', '--filepath', filepath, '--port', '3334'])
public_url = ngrok.connect(3334)
print(f"Access Carbonboard at: {public_url}")

# %% [markdown]
# # MobileNet-V2 + BiLSTM

# %%
from pyngrok import ngrok
import subprocess

# !ngrok authtoken '2hs9Eao8fUVN21iEhE0uXVALvqf_3zETHYg3XTAUXE63cZ1s3'

filepath = "/content/gdrive/MyDrive/Modelli/MobileNet_V2/BiLSTM/Emissioni_addestramento_MV2_BiLSTM.csv"
carbonboard_process = subprocess.Popen(['carbonboard', '--filepath', filepath, '--port', '3335'])
public_url = ngrok.connect(3335)
print(f"Access Carbonboard at: {public_url}")

# %% [markdown]
# # MobileNet-V2 + ConvLSTM

# %%
from pyngrok import ngrok
import subprocess

# !ngrok authtoken '2hs9Eao8fUVN21iEhE0uXVALvqf_3zETHYg3XTAUXE63cZ1s3'

filepath = "/content/gdrive/MyDrive/Modelli/MobileNet_V2/ConvLSTM/Addestramento_MV2_ConvLSTM.csv"
carbonboard_process = subprocess.Popen(['carbonboard', '--filepath', filepath, '--port', '3336'])
public_url = ngrok.connect(3336)
print(f"Access Carbonboard at: {public_url}")

# %% [markdown]
# # C3D + SVM

# %%
from pyngrok import ngrok
import subprocess

# !ngrok authtoken '2hs9Eao8fUVN21iEhE0uXVALvqf_3zETHYg3XTAUXE63cZ1s3'

filepath = "/content/gdrive/MyDrive/Modelli/C3D_SVM/Split_Multipli/Addestramento_C3D_SVM.csv"
carbonboard_process = subprocess.Popen(['carbonboard', '--filepath', filepath, '--port', '3337'])
public_url = ngrok.connect(3337)
print(f"Access Carbonboard at: {public_url}")
